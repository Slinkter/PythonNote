# %%
# ls

# %%
import pandas as pd

# %%
# load data
data = pd.read_csv("Pokemon.csv" ,index_col = '#')

# %%
# ver datos
data
# Out:
#                           Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# #
# 1                    Bulbasaur     Grass  Poison    318   45      49       49
# 2                      Ivysaur     Grass  Poison    405   60      62       63
# 3                     Venusaur     Grass  Poison    525   80      82       83
# 3        VenusaurMega Venusaur     Grass  Poison    625   80     100      123
# 4                   Charmander      Fire     NaN    309   39      52       43
# 5                   Charmeleon      Fire     NaN    405   58      64       58
# 6                    Charizard      Fire  Flying    534   78      84       78
# 6    CharizardMega Charizard X      Fire  Dragon    634   78     130      111
# 6    CharizardMega Charizard Y      Fire  Flying    634   78     104       78
# 7                     Squirtle     Water     NaN    314   44      48       65
# 8                    Wartortle     Water     NaN    405   59      63       80
# ...

# %%
data['Name'].head(5)
# Out:
# #
# 1                Bulbasaur
# 2                  Ivysaur
# 3                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
data.Name.head(5)
# Out:
# #
# 1                Bulbasaur
# 2                  Ivysaur
# 3                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
(data.Name == data['Name']).all()
# Out:
# True

# %%
# video 12

# %%
#dir(data['Total'])

# %%
data['Total'].max()
# Out:
# 780

# %%
valor_maximo = data['Total'].max()

# %%
data[data['Total'] == valor_maximo]
# Out:
#                       Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150       70
# 384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180      100
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary  total
# #
# 150      154      100    130           1      True    780
# 150      194      120    140           1      True    780
# 384      180      100    115           3      True    780

# %%
data[data['Total'] == valor_maximo]['Name']
# Out:
# #
# 150      MewtwoMega Mewtwo X
# 150      MewtwoMega Mewtwo Y
# 384    RayquazaMega Rayquaza
# Name: Name, dtype: object

# %%
data['Speed'].mean()
# Out:
# 68.2775

# %%
# %matplotlib inline

# %% [markdown]
# # ver Datos

# %%
data['Attack'].hist()

# %%
data['Attack'].min()
# Out:
# 5

# %%
data['Attack'].max()
# Out:
# 190

# %% [markdown]
# # Ver Por tipo 1 y tipo 2

# %%
data['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data['Type 2'].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Rock        14
# Ghost       14
# Ice         14
# Water       14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
data.groupby('Type 1')['Total'].mean().sort_values(ascending=False)
# Out:
# Type 1
# Dragon      550.531250
# Steel       487.703704
# Flying      485.000000
# Psychic     475.947368
# Fire        458.076923
# Rock        453.750000
# Dark        445.741935
# Electric    443.409091
# Ghost       439.562500
# Ground      437.500000
# Ice         433.458333
# Water       430.455357
# Grass       421.142857
# Fighting    416.444444
# Fairy       413.176471
# Normal      401.683673
# Poison      399.142857
# Bug         378.927536
# Name: Total, dtype: float64

# %%
data.groupby(['Type 1','Type 2'])['Attack'].max().sort_values(ascending=False)
# Out:
# Type 1    Type 2
# Psychic   Fighting    190
# Bug       Fighting    185
# Ground    Fire        180
# Dragon    Flying      180
#           Ice         170
#           Ground      170
# Rock      Dark        164
# Fire      Fighting    160
# Rock      Fairy       160
# Psychic   Dark        160
# Water     Dark        155
# Bug       Flying      155
#           Poison      150
# Dragon    Electric    150
# Steel     Ghost       150
# Water     Ground      150
# Bug       Steel       150
# Fighting  Steel       145
# Steel     Psychic     145
# Ground    Flying      145
# Rock      Flying      140
# Ground    Rock        140
# Normal    Fighting    136
# Ground    Steel       135
# Grass     Ice         132
# Dark      Flying      131
# Fire      Flying      130
# Ice       Ground      130
# Dragon    Psychic     130
# Grass     Fighting    130
#                      ...
# Poison    Dragon       75
# Electric  Steel        70
# Water     Grass        70
# Ground    Psychic      70
# ...

# %%
data.head(3)
# Out:
#         Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation Legendary
# #
# 1     45           1     False
# 2     60           1     False
# 3     80           1     False

# %%
import seaborn as sns
sns.set(style="white", color_codes=True)

# %%
#Extra en windows
import matplotlib.pyplot as plt

# %%
#sns.jointplot(x='Sp. Atk', y='Sp. Def',data=data,kind='hex')
sns.jointplot(x='Sp. Atk', y='Sp. Def',data=data,kind='kde').plot
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.boxplot(data =data.drop(['Name','Total','Generation','Legendary'] , axis=1).head()).plot
plt.show()

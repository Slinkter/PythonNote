# %% [markdown]
# diccionario = {"nombre":"Carla"}

# %%
diccionario = {"nombre":"Luis" ,"Apellido": "Cueva","Edad": "26 años"}

# %%
print(diccionario)
# Out:
# {'nombre': 'Luis', 'Apellido': 'Cueva', 'Edad': '26 años'}

# %%
variable_texto = "hola como ESTAS" 
print(variable_texto.lower())
# Out:
# hola como estas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.19.2'

# %%
data=pd.read_excel("datos.xlsx")

# %%
data
# Out:
#                  Timestamp Dependencia  \
# 0  2016-08-09 10:15:54.846     CENDI I
# 1  2016-08-09 10:16:32.998     CENDI I
# 2  2016-08-09 10:23:11.433     CENDI I
# 3  2016-08-09 10:26:13.569     CENDI I
# 4  2016-08-09 10:27:14.245     CENDI I
# 5  2016-08-09 10:27:46.680     CENDI I
# 6  2016-08-09 10:28:32.199     CENDI I
# 7  2016-08-09 10:29:05.311     CENDI I
# 8  2016-08-09 10:29:30.980     CENDI I
# 9  2016-08-09 10:30:14.015     CENDI I
# 10 2016-08-09 10:30:43.602     CENDI I
# 11 2016-08-09 10:31:16.614     CENDI I
# 12 2016-08-09 10:31:50.926     CENDI I
# 13 2016-08-09 10:32:25.645     CENDI I
# 14 2016-08-09 10:33:14.859     CENDI I
# 15 2016-08-09 10:33:48.211     CENDI I
# 16 2016-08-09 10:34:27.736     CENDI I
# 17 2016-08-09 10:34:53.978     CENDI I
# 18 2016-08-09 10:35:19.965     CENDI I
# 19 2016-08-09 10:36:11.393     CENDI I
# 20 2016-08-09 10:38:39.767    CENDI II
# 21 2016-08-09 10:39:17.417    CENDI II
# 22 2016-08-09 10:39:50.251    CENDI II
# ...

# %%
data.head(5)
# Out:
#                 Timestamp Dependencia  \
# 0 2016-08-09 10:15:54.846     CENDI I
# 1 2016-08-09 10:16:32.998     CENDI I
# 2 2016-08-09 10:23:11.433     CENDI I
# 3 2016-08-09 10:26:13.569     CENDI I
# 4 2016-08-09 10:27:14.245     CENDI I
#
#   1.\t¿Qué motivo la llevó a convertirse en Jefa de Hogar?   \
# 0                                   b) Madre Soltera
# 1                                   b) Madre Soltera
# 2                                   b) Madre Soltera
# 3                                        c) Divorcio
# 4                                   b) Madre Soltera
#
#   2.\t¿Cuáles son las principales problemáticas a las que se enfrenta diariamente como Jefa de Hogar?  \
# 0  b) Falta de horarios extendidos en guardería, ...
# 1                                  d) Salarios bajos
# 2  b) Falta de horarios extendidos en guardería, ...
# 3                                  d) Salarios bajos
# 4                                  d) Salarios bajos
#
# ...

# %%
data.tail(5)
# Out:
#                  Timestamp Dependencia  \
# 38 2016-08-12 12:45:34.227     CENDI V
# 39 2016-08-12 12:46:22.075     CENDI V
# 40 2016-08-12 12:47:06.954     CENDI V
# 41 2016-08-12 12:47:33.594     CENDI V
# 42 2016-08-12 12:48:13.391     CENDI V
#
#    1.\t¿Qué motivo la llevó a convertirse en Jefa de Hogar?   \
# 38                                      d) Separación
# 39                                   b) Madre Soltera
# 40                                      d) Separación
# 41                                      d) Separación
# 42                                   b) Madre Soltera
#
#    2.\t¿Cuáles son las principales problemáticas a las que se enfrenta diariamente como Jefa de Hogar?  \
# 38                   a) Pocas oportunidades de empleo
# 39                   a) Pocas oportunidades de empleo
# 40       b) Falta de horarios extendidos en guardería
# 41       b) Falta de horarios extendidos en guardería
# 42                   a) Pocas oportunidades de empleo
#
# ...

# %%
data.columns.values
# Out:
# array(['Timestamp', 'Dependencia',
#        '1.\t¿Qué motivo la llevó a convertirse en Jefa de Hogar? ',
#        '2.\t¿Cuáles son las principales problemáticas a las que se enfrenta diariamente como Jefa de Hogar?',
#        '3.\t¿Qué factor considera que en mayor medida impide el desarrollo integral (Educación, Salud, Nutrición, etc.) de una Jefa de Hogar? (Seleccionar 1)',
#        '4.\t¿Conoce programas y/o acciones de gobierno o asociaciones que les sirvan de apoyo a las Jefas de Hogar? En caso de conocer alguno, ¿Cuál es?',
#        '5.\tDe los servicios municipales mencionados a continuación, ¿Cuáles ha utilizado?',
#        '6.\t¿Qué tipo de apoyo le gustaría recibir por parte del gobierno municipal o de asociaciones?'], dtype=object)

# %%
data=pd.read_excel("datos.xlsx",names=["Timestamp","Dependencia","Porque","Problematicas ","Factor","Programas","Servicio","Apoyos"])

# %%
data
# Out:
#                  Timestamp Dependencia  \
# 0  2016-08-09 10:15:54.846     CENDI I
# 1  2016-08-09 10:16:32.998     CENDI I
# 2  2016-08-09 10:23:11.433     CENDI I
# 3  2016-08-09 10:26:13.569     CENDI I
# 4  2016-08-09 10:27:14.245     CENDI I
# 5  2016-08-09 10:27:46.680     CENDI I
# 6  2016-08-09 10:28:32.199     CENDI I
# 7  2016-08-09 10:29:05.311     CENDI I
# 8  2016-08-09 10:29:30.980     CENDI I
# 9  2016-08-09 10:30:14.015     CENDI I
# 10 2016-08-09 10:30:43.602     CENDI I
# 11 2016-08-09 10:31:16.614     CENDI I
# 12 2016-08-09 10:31:50.926     CENDI I
# 13 2016-08-09 10:32:25.645     CENDI I
# 14 2016-08-09 10:33:14.859     CENDI I
# 15 2016-08-09 10:33:48.211     CENDI I
# 16 2016-08-09 10:34:27.736     CENDI I
# 17 2016-08-09 10:34:53.978     CENDI I
# 18 2016-08-09 10:35:19.965     CENDI I
# 19 2016-08-09 10:36:11.393     CENDI I
# 20 2016-08-09 10:38:39.767    CENDI II
# 21 2016-08-09 10:39:17.417    CENDI II
# 22 2016-08-09 10:39:50.251    CENDI II
# ...

# %%
print(data.columns.values)
# Out:
# ['Timestamp' 'Dependencia' 'Porque' 'Problematicas ' 'Factor' 'Programas'
#  'Servicio' 'Apoyos']

# %%
c1 = data["Timestamp"]
c2 = data["Dependencia"]
c3 = data["Porque"]
c4 = data["Problematicas "]
c5 = data["Factor"]
c6 = data["Programas"]
c7 = data["Servicio"]
c8 = data["Apoyos"]

# %%
# %matplotlib inline

# %%
pd.value_counts(c4).plot("bar")

# %%
pd.value_counts(c2).plot("bar")

# %%
data
# Out:
#                  Timestamp Dependencia  \
# 0  2016-08-09 10:15:54.846     CENDI I
# 1  2016-08-09 10:16:32.998     CENDI I
# 2  2016-08-09 10:23:11.433     CENDI I
# 3  2016-08-09 10:26:13.569     CENDI I
# 4  2016-08-09 10:27:14.245     CENDI I
# 5  2016-08-09 10:27:46.680     CENDI I
# 6  2016-08-09 10:28:32.199     CENDI I
# 7  2016-08-09 10:29:05.311     CENDI I
# 8  2016-08-09 10:29:30.980     CENDI I
# 9  2016-08-09 10:30:14.015     CENDI I
# 10 2016-08-09 10:30:43.602     CENDI I
# 11 2016-08-09 10:31:16.614     CENDI I
# 12 2016-08-09 10:31:50.926     CENDI I
# 13 2016-08-09 10:32:25.645     CENDI I
# 14 2016-08-09 10:33:14.859     CENDI I
# 15 2016-08-09 10:33:48.211     CENDI I
# 16 2016-08-09 10:34:27.736     CENDI I
# 17 2016-08-09 10:34:53.978     CENDI I
# 18 2016-08-09 10:35:19.965     CENDI I
# 19 2016-08-09 10:36:11.393     CENDI I
# 20 2016-08-09 10:38:39.767    CENDI II
# 21 2016-08-09 10:39:17.417    CENDI II
# 22 2016-08-09 10:39:50.251    CENDI II
# ...

# %%
cendi_1 = data[c2 == "CENDI I"]

# %%
cendi_1
# Out:
#                  Timestamp Dependencia  \
# 0  2016-08-09 10:15:54.846     CENDI I
# 1  2016-08-09 10:16:32.998     CENDI I
# 2  2016-08-09 10:23:11.433     CENDI I
# 3  2016-08-09 10:26:13.569     CENDI I
# 4  2016-08-09 10:27:14.245     CENDI I
# 5  2016-08-09 10:27:46.680     CENDI I
# 6  2016-08-09 10:28:32.199     CENDI I
# 7  2016-08-09 10:29:05.311     CENDI I
# 8  2016-08-09 10:29:30.980     CENDI I
# 9  2016-08-09 10:30:14.015     CENDI I
# 10 2016-08-09 10:30:43.602     CENDI I
# 11 2016-08-09 10:31:16.614     CENDI I
# 12 2016-08-09 10:31:50.926     CENDI I
# 13 2016-08-09 10:32:25.645     CENDI I
# 14 2016-08-09 10:33:14.859     CENDI I
# 15 2016-08-09 10:33:48.211     CENDI I
# 16 2016-08-09 10:34:27.736     CENDI I
# 17 2016-08-09 10:34:53.978     CENDI I
# 18 2016-08-09 10:35:19.965     CENDI I
# 19 2016-08-09 10:36:11.393     CENDI I
#
#                                                Porque  \
# 0                                    b) Madre Soltera
# ...

# %%
def f_grafica_problematicas(valores):
   pd.value_counts(valores).plot("bar")
    return "grafica existosa"

# %%
f_grafica_problematicas(pd.value_counts(c2).plot("bar"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-f576ab12d3c3> in <module>()
# ----> 1 f_grafica_problematicas(cendi_1)
#
# <ipython-input-34-05abef7046c4> in f_grafica_problematicas(valores)
#       1 def f_grafica_problematicas(valores):
# ----> 2     pd.value_counts(valores[c4]).plot("bar")
#       3     return "grafica existosa"
#
# D:\Python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2051         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2052             # either boolean or fancy integer index
# -> 2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
#    2055             return self._getitem_frame(key)
#
# D:\Python\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2095             return self.take(indexer, axis=0, convert=False)
# ...
